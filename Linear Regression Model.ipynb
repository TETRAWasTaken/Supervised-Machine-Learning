# %% [markdown]
# # Linear Regression Model

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv('Datasets/Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = df.iloc[:,0].values
Y = df.iloc[:,1].values

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
X_train , X_test, Y_train = X_train.reshape(-1,1), X_test.reshape(-1,1), Y_train.reshape(-1,1)

# %% [markdown]
# ## Training the Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Plotting the Outcome

# %%
plt.scatter(X_train, Y_train, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
y_pred = regressor.predict(X_test)
for i in range(len(y_pred)):
    print("Predicted Salary:", y_pred[i][0], " | Actual Salary:", Y_test[i])
# Out:
# Predicted Salary: 75074.50510971624  | Actual Salary: 83088.0
# Predicted Salary: 91873.80563810313  | Actual Salary: 98273.0
# Predicted Salary: 62008.38247652643  | Actual Salary: 63218.0
# Predicted Salary: 81607.56642631114  | Actual Salary: 93940.0
# Predicted Salary: 67608.14931932205  | Actual Salary: 61111.0
# Predicted Salary: 89073.92221670531  | Actual Salary: 91738.0

# %%
def MeanSquaredError(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    '''Arithmetic mean of squared differences between prediction and actual observation.'''
    AE = y_true - y_pred
    SE = AE ** 2
    MSE = SE.mean()
    return MSE

# %%
print("Mean Squared Error:", MeanSquaredError(Y_test, y_pred))
# Out:
# Mean Squared Error: 348287437.2025421
